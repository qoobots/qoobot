# %% [markdown]
# # QooBrain Perception Demo
#
# 演示感知管线：目标检测 → 场景构建 → 语义理解。

# %%
import sys
sys.path.insert(0, '..')

from brain_ai.perception.scene_aggregator import SceneAggregator
from brain_ai.perception.detector import YOLODetector

detector = YOLODetector()
aggregator = SceneAggregator()
print("Perception module loaded")
